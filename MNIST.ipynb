# %% [markdown]
# <a href="https://colab.research.google.com/github/Killian091/Machine_Learning/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MNIST** - Classification

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
X,y = mnist['data'], mnist['target']

# %%
X.shape
# Out:
# (70000, 784)
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)
# (70000,)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
some_digit = X.iloc[0]
some_digit_image = some_digit.values.reshape(28,28)

# %%
some_digit
# Out:
# pixel1      0
# pixel2      0
# pixel3      0
# pixel4      0
# pixel5      0
#            ..
# pixel780    0
# pixel781    0
# pixel782    0
# pixel783    0
# pixel784    0
# Name: 0, Length: 784, dtype: int64
# pixel1      0
# pixel2      0
# pixel3      0
# pixel4      0
# pixel5      0
#            ..
# pixel780    0
# pixel781    0
# pixel782    0
# pixel783    0
# pixel784    0
# Name: 0, Length: 784, dtype: int64

# %%
plt.imshow(some_digit_image, cmap = mpl.cm.binary, interpolation="nearest")
plt.axis("off")
plt.show()

# %%
y = y.astype(int)

# %% [markdown]
# ## **Train** **Test** **Split**

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %%
y_train_5 = (y_train == 5)
y_test_5 = (y_test == 5)

# %%
from sklearn.linear_model import SGDClassifier

sdg_clf = SGDClassifier(random_state=42)
sdg_clf.fit(X_train,y_train)
