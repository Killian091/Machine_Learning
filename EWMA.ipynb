# %% [markdown]
# <a href="https://colab.research.google.com/github/Killian091/Machine_Learning/blob/main/EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EWMA - Exponentially Weighted Moving Average**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('daily_temperature.csv')

# %%
df.head()
# Out:
#          date  meantemp
# 0  2025-01-01      15.5
# 1  2025-01-02      13.8
# 2  2025-01-03      15.1
# 3  2025-01-04      15.4
# 4  2025-01-05      17.6

# %%
plt.scatter(df['date'],df['meantemp'], c='red')
plt.title('Daily Temperature')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.show()

# %%
x1 = df['meantemp'].ewm(alpha=0.65).mean()

# %%
x1
# Out:
# 0      15.500000
# 1      14.240741
# 2      14.824278
# 3      15.204199
# 4      16.769692
#          ...
# 115    28.537820
# 116    27.733237
# 117    28.556633
# 118    28.974822
# 119    28.276188
# Name: meantemp, Length: 120, dtype: float64

# %%
df['ewma'] = x1
df
# Out:
#            date  meantemp       ewma
# 0    2025-01-01      15.5  15.500000
# 1    2025-01-02      13.8  14.240741
# 2    2025-01-03      15.1  14.824278
# 3    2025-01-04      15.4  15.204199
# 4    2025-01-05      17.6  16.769692
# ..          ...       ...        ...
# 115  2025-04-26      29.0  28.537820
# 116  2025-04-27      27.3  27.733237
# 117  2025-04-28      29.0  28.556633
# 118  2025-04-29      29.2  28.974822
# 119  2025-04-30      27.9  28.276188
#
# [120 rows x 3 columns]

# %%
plt.scatter(df['date'], df['meantemp'], color='red')
plt.plot(df['date'], df['ewma'], color='black')
plt.title('Daily Temperature')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.show()
